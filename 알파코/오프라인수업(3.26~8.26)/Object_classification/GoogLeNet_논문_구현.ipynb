# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonwanggyu/Self_Study/blob/main/%EC%98%A4%ED%94%84%EB%9D%BC%EC%9D%B8/GoogLeNet_%EB%85%BC%EB%AC%B8_%EA%B5%AC%ED%98%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GoogleNet 구조

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

import matplotlib.pyplot as plt

# %% [markdown]
# Inception module

# %%
from tensorflow.keras import layers

def inception(input, n_1x1, n_3x3r, n_3x3, n_5x5r, n_5x5, n_pool, idx_layer):
    name_layer = f"inception_{idx_layer}"

    # 1x1 컨볼루션
    conv_1x1 = layers.Conv2D(filters=n_1x1, kernel_size=(1, 1), padding='same', activation='relu', name=f'{name_layer}/1x1')(input)

    # 3x3 컨볼루션
    conv_3x3_reduce = layers.Conv2D(filters=n_3x3r, kernel_size=(1, 1), padding='same', activation='relu', name=f'{name_layer}/3x3_reduce')(input)
    conv_3x3 = layers.Conv2D(filters=n_3x3, kernel_size=(3, 3), padding='same', activation='relu', name=f'{name_layer}/3x3')(conv_3x3_reduce)

    # 5x5 컨볼루션
    conv_5x5_reduce = layers.Conv2D(filters=n_5x5r, kernel_size=(1, 1), padding='same', activation='relu', name=f'{name_layer}/5x5_reduce')(input)
    conv_5x5 = layers.Conv2D(filters=n_5x5, kernel_size=(5, 5), padding='same', activation='relu', name=f'{name_layer}/5x5')(conv_5x5_reduce)

    # 풀링
    pool = layers.MaxPooling2D(pool_size=(3, 3), strides=1, padding='same', name=f'{name_layer}/pool')(input)
    pool_proj = layers.Conv2D(filters=n_pool, kernel_size=(1, 1), padding='same', activation='relu', name=f'{name_layer}/pool_proj')(pool)

    # 필터 결합
    output = layers.Concatenate(axis=-1, name=f'{name_layer}/output')([conv_1x1, conv_3x3, conv_5x5, pool_proj])

    return output

# %%
def auxilary_cls(input,name=None):
    x = layers.AveragePooling2D(pool_size=(5,5),strides=(3,3))(input)
    x = layers.Conv2D(128,(1,1),strides=1,padding='same',activation='relu')(x)
    x = layers.Flatten()(x)
    x = layers.Dense(256,activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(10,activation='softmax')(x)
    return x

# %%
def create_googlenet():
    # creates GoogLeNet a.k.a. Inception v1 (Szegedy, 2015)
    input = tf.keras.Input(shape=(224, 224, 3))

    # conv 1 + maxpool 1
    x = layers.Conv2D(64,(7,7),strides=(2,2),activation='relu',padding='same')(input)
    x = layers.MaxPooling2D((3,3),strides=2,padding='same')(x)
    x = layers.Lambda(tf.nn.local_response_normalization)(x)

    # conv 2 (1x1 : 64, 3x3 : 192) + maxpool 2
    x = layers.Conv2D(64,(1,1),strides=1,activation='relu',padding='same')(x)
    x = layers.Conv2D(192,(3,3),strides=1,activation='relu',padding='same')(x)
    x = layers.Lambda(tf.nn.local_response_normalization)(x)
    x = layers.MaxPooling2D((3,3),strides=2,padding='same')(x)

    # Inception 3a ############################################################
    x = inception(x,64,96,128,16,32,32,'3a')
    x = inception(x,128,128,192,32,96,64,'3b')
    x = layers.MaxPooling2D((3,3),strides=2,padding='same')(x)

    # Inception 4a/4b ############################################################
    x = inception(x,192,96,208,16,48,48,'4a')
    x = inception(x,160,112,224,24,64,64,'4b')

        # auxiliary classifier **********************
    aux_1 = auxilary_cls(x)

    # Inception 4c/4d/4e ############################################################
    x = inception(x,128,128,256,24,64,64,'4c')
    x = inception(x,112,144,288,32,64,64,'4d')
    x = inception(x,256,160,320,32,128,128,'4e')
    x = layers.MaxPooling2D((3,3),strides=2,padding='same')(x)

        # auxiliary classifier **********************
    aux_2 = auxilary_cls(x)

    # Inception 5a/5b ############################################################
    x = inception(x,256,160,320,32,128,128,'5a')
    x = inception(x,384,192,384,48,128,128,'5b')
    x = layers.AveragePooling2D((7,7),strides=1,padding='same')(x)

    x = layers.Flatten()(x)
    x = layers.Dropout(0.4)(x)

    output = layers.Dense(10,activation='softmax')(x)

   # Final Model : input + output[aux.cls1, aux.cls2, main.cls]
    model = tf.keras.Model(inputs=input, outputs=[aux_1,aux_2,output])

    return model

# %%
model = create_googlenet()

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_13 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_39 (Conv2D)          (None, 112, 112, 64)         9472      ['input_13[0][0]']
#
#  max_pooling2d_30 (MaxPooli  (None, 56, 56, 64)           0         ['conv2d_39[0][0]']
#  ng2D)
#
#  lambda_14 (Lambda)          (None, 56, 56, 64)           0         ['max_pooling2d_30[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 56, 56, 64)           4160      ['lambda_14[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 56, 56, 192)          110784    ['conv2d_40[0][0]']
#
#  lambda_15 (Lambda)          (None, 56, 56, 192)          0         ['conv2d_41[0][0]']
#
#  max_pooling2d_31 (MaxPooli  (None, 28, 28, 192)          0         ['lambda_15[0][0]']
#  ng2D)
#
#  inception_3a/3x3_reduce (C  (None, 28, 28, 96)           18528     ['max_pooling2d_31[0][0]']
#  onv2D)
#
#  inception_3a/5x5_reduce (C  (None, 28, 28, 16)           3088      ['max_pooling2d_31[0][0]']
#  onv2D)
#
#  inception_3a/pool (MaxPool  (None, 28, 28, 192)          0         ['max_pooling2d_31[0][0]']
#  ing2D)
#
#  inception_3a/1x1 (Conv2D)   (None, 28, 28, 64)           12352     ['max_pooling2d_31[0][0]']
#
#  inception_3a/3x3 (Conv2D)   (None, 28, 28, 128)          110720    ['inception_3a/3x3_reduce[0][0
#                                                                     ]']
#
#  inception_3a/5x5 (Conv2D)   (None, 28, 28, 32)           12832     ['inception_3a/5x5_reduce[0][0
#                                                                     ]']
#
#  inception_3a/pool_proj (Co  (None, 28, 28, 32)           6176      ['inception_3a/pool[0][0]']
#  nv2D)
#
#  inception_3a/output (Conca  (None, 28, 28, 256)          0         ['inception_3a/1x1[0][0]',
#  tenate)                                                             'inception_3a/3x3[0][0]',
#                                                                      'inception_3a/5x5[0][0]',
#                                                                      'inception_3a/pool_proj[0][0]
#                                                                     ']
#
#  inception_3b/3x3_reduce (C  (None, 28, 28, 128)          32896     ['inception_3a/output[0][0]']
#  onv2D)
#
#  inception_3b/5x5_reduce (C  (None, 28, 28, 32)           8224      ['inception_3a/output[0][0]']
#  onv2D)
#
#  inception_3b/pool (MaxPool  (None, 28, 28, 256)          0         ['inception_3a/output[0][0]']
#  ing2D)
#
#  inception_3b/1x1 (Conv2D)   (None, 28, 28, 128)          32896     ['inception_3a/output[0][0]']
#
#  inception_3b/3x3 (Conv2D)   (None, 28, 28, 192)          221376    ['inception_3b/3x3_reduce[0][0
#                                                                     ]']
#
#  inception_3b/5x5 (Conv2D)   (None, 28, 28, 96)           76896     ['inception_3b/5x5_reduce[0][0
#                                                                     ]']
#
#  inception_3b/pool_proj (Co  (None, 28, 28, 64)           16448     ['inception_3b/pool[0][0]']
#  nv2D)
#
#  inception_3b/output (Conca  (None, 28, 28, 480)          0         ['inception_3b/1x1[0][0]',
#  tenate)                                                             'inception_3b/3x3[0][0]',
#                                                                      'inception_3b/5x5[0][0]',
#                                                                      'inception_3b/pool_proj[0][0]
#                                                                     ']
#
#  max_pooling2d_32 (MaxPooli  (None, 14, 14, 480)          0         ['inception_3b/output[0][0]']
#  ng2D)
#
#  inception_4a/3x3_reduce (C  (None, 14, 14, 96)           46176     ['max_pooling2d_32[0][0]']
#  onv2D)
#
#  inception_4a/5x5_reduce (C  (None, 14, 14, 16)           7696      ['max_pooling2d_32[0][0]']
#  onv2D)
#
#  inception_4a/pool (MaxPool  (None, 14, 14, 480)          0         ['max_pooling2d_32[0][0]']
#  ing2D)
#
#  inception_4a/1x1 (Conv2D)   (None, 14, 14, 192)          92352     ['max_pooling2d_32[0][0]']
#
#  inception_4a/3x3 (Conv2D)   (None, 14, 14, 208)          179920    ['inception_4a/3x3_reduce[0][0
#                                                                     ]']
#
#  inception_4a/5x5 (Conv2D)   (None, 14, 14, 48)           19248     ['inception_4a/5x5_reduce[0][0
#                                                                     ]']
#
#  inception_4a/pool_proj (Co  (None, 14, 14, 48)           23088     ['inception_4a/pool[0][0]']
#  nv2D)
#
#  inception_4a/output (Conca  (None, 14, 14, 496)          0         ['inception_4a/1x1[0][0]',
#  tenate)                                                             'inception_4a/3x3[0][0]',
#                                                                      'inception_4a/5x5[0][0]',
#                                                                      'inception_4a/pool_proj[0][0]
#                                                                     ']
#
#  inception_4b/3x3_reduce (C  (None, 14, 14, 112)          55664     ['inception_4a/output[0][0]']
#  onv2D)
#
#  inception_4b/5x5_reduce (C  (None, 14, 14, 24)           11928     ['inception_4a/output[0][0]']
#  onv2D)
#
#  inception_4b/pool (MaxPool  (None, 14, 14, 496)          0         ['inception_4a/output[0][0]']
#  ing2D)
#
#  inception_4b/1x1 (Conv2D)   (None, 14, 14, 160)          79520     ['inception_4a/output[0][0]']
#
#  inception_4b/3x3 (Conv2D)   (None, 14, 14, 224)          226016    ['inception_4b/3x3_reduce[0][0
#                                                                     ]']
#
#  inception_4b/5x5 (Conv2D)   (None, 14, 14, 64)           38464     ['inception_4b/5x5_reduce[0][0
#                                                                     ]']
#
#  inception_4b/pool_proj (Co  (None, 14, 14, 64)           31808     ['inception_4b/pool[0][0]']
#  nv2D)
#
#  inception_4b/output (Conca  (None, 14, 14, 512)          0         ['inception_4b/1x1[0][0]',
#  tenate)                                                             'inception_4b/3x3[0][0]',
#                                                                      'inception_4b/5x5[0][0]',
#                                                                      'inception_4b/pool_proj[0][0]
#                                                                     ']
#
#  inception_4c/3x3_reduce (C  (None, 14, 14, 128)          65664     ['inception_4b/output[0][0]']
#  onv2D)
#
#  inception_4c/5x5_reduce (C  (None, 14, 14, 24)           12312     ['inception_4b/output[0][0]']
#  onv2D)
#
#  inception_4c/pool (MaxPool  (None, 14, 14, 512)          0         ['inception_4b/output[0][0]']
#  ing2D)
#
#  inception_4c/1x1 (Conv2D)   (None, 14, 14, 128)          65664     ['inception_4b/output[0][0]']
#
#  inception_4c/3x3 (Conv2D)   (None, 14, 14, 256)          295168    ['inception_4c/3x3_reduce[0][0
#                                                                     ]']
#
#  inception_4c/5x5 (Conv2D)   (None, 14, 14, 64)           38464     ['inception_4c/5x5_reduce[0][0
#                                                                     ]']
#
#  inception_4c/pool_proj (Co  (None, 14, 14, 64)           32832     ['inception_4c/pool[0][0]']
#  nv2D)
#
#  inception_4c/output (Conca  (None, 14, 14, 512)          0         ['inception_4c/1x1[0][0]',
#  tenate)                                                             'inception_4c/3x3[0][0]',
#                                                                      'inception_4c/5x5[0][0]',
#                                                                      'inception_4c/pool_proj[0][0]
#                                                                     ']
#
#  inception_4d/3x3_reduce (C  (None, 14, 14, 144)          73872     ['inception_4c/output[0][0]']
#  onv2D)
#
#  inception_4d/5x5_reduce (C  (None, 14, 14, 32)           16416     ['inception_4c/output[0][0]']
#  onv2D)
#
#  inception_4d/pool (MaxPool  (None, 14, 14, 512)          0         ['inception_4c/output[0][0]']
#  ing2D)
#
#  inception_4d/1x1 (Conv2D)   (None, 14, 14, 112)          57456     ['inception_4c/output[0][0]']
#
#  inception_4d/3x3 (Conv2D)   (None, 14, 14, 288)          373536    ['inception_4d/3x3_reduce[0][0
#                                                                     ]']
#
#  inception_4d/5x5 (Conv2D)   (None, 14, 14, 64)           51264     ['inception_4d/5x5_reduce[0][0
#                                                                     ]']
#
#  inception_4d/pool_proj (Co  (None, 14, 14, 64)           32832     ['inception_4d/pool[0][0]']
#  nv2D)
#
#  inception_4d/output (Conca  (None, 14, 14, 528)          0         ['inception_4d/1x1[0][0]',
#  tenate)                                                             'inception_4d/3x3[0][0]',
#                                                                      'inception_4d/5x5[0][0]',
#                                                                      'inception_4d/pool_proj[0][0]
#                                                                     ']
#
#  inception_4e/3x3_reduce (C  (None, 14, 14, 160)          84640     ['inception_4d/output[0][0]']
#  onv2D)
#
#  inception_4e/5x5_reduce (C  (None, 14, 14, 32)           16928     ['inception_4d/output[0][0]']
#  onv2D)
#
#  inception_4e/pool (MaxPool  (None, 14, 14, 528)          0         ['inception_4d/output[0][0]']
#  ing2D)
#
#  inception_4e/1x1 (Conv2D)   (None, 14, 14, 256)          135424    ['inception_4d/output[0][0]']
#
#  inception_4e/3x3 (Conv2D)   (None, 14, 14, 320)          461120    ['inception_4e/3x3_reduce[0][0
#                                                                     ]']
#
#  inception_4e/5x5 (Conv2D)   (None, 14, 14, 128)          102528    ['inception_4e/5x5_reduce[0][0
#                                                                     ]']
#
#  inception_4e/pool_proj (Co  (None, 14, 14, 128)          67712     ['inception_4e/pool[0][0]']
#  nv2D)
#
#  inception_4e/output (Conca  (None, 14, 14, 832)          0         ['inception_4e/1x1[0][0]',
#  tenate)                                                             'inception_4e/3x3[0][0]',
#                                                                      'inception_4e/5x5[0][0]',
#                                                                      'inception_4e/pool_proj[0][0]
#                                                                     ']
#
#  max_pooling2d_33 (MaxPooli  (None, 7, 7, 832)            0         ['inception_4e/output[0][0]']
#  ng2D)
#
#  inception_5a/3x3_reduce (C  (None, 7, 7, 160)            133280    ['max_pooling2d_33[0][0]']
#  onv2D)
#
#  inception_5a/5x5_reduce (C  (None, 7, 7, 32)             26656     ['max_pooling2d_33[0][0]']
#  onv2D)
#
#  inception_5a/pool (MaxPool  (None, 7, 7, 832)            0         ['max_pooling2d_33[0][0]']
#  ing2D)
#
#  inception_5a/1x1 (Conv2D)   (None, 7, 7, 256)            213248    ['max_pooling2d_33[0][0]']
#
#  inception_5a/3x3 (Conv2D)   (None, 7, 7, 320)            461120    ['inception_5a/3x3_reduce[0][0
#                                                                     ]']
#
#  inception_5a/5x5 (Conv2D)   (None, 7, 7, 128)            102528    ['inception_5a/5x5_reduce[0][0
#                                                                     ]']
#
#  inception_5a/pool_proj (Co  (None, 7, 7, 128)            106624    ['inception_5a/pool[0][0]']
#  nv2D)
#
#  inception_5a/output (Conca  (None, 7, 7, 832)            0         ['inception_5a/1x1[0][0]',
#  tenate)                                                             'inception_5a/3x3[0][0]',
#                                                                      'inception_5a/5x5[0][0]',
#                                                                      'inception_5a/pool_proj[0][0]
#                                                                     ']
#
#  inception_5b/3x3_reduce (C  (None, 7, 7, 192)            159936    ['inception_5a/output[0][0]']
#  onv2D)
#
#  inception_5b/5x5_reduce (C  (None, 7, 7, 48)             39984     ['inception_5a/output[0][0]']
#  onv2D)
#
#  inception_5b/pool (MaxPool  (None, 7, 7, 832)            0         ['inception_5a/output[0][0]']
#  ing2D)
#
#  average_pooling2d_13 (Aver  (None, 4, 4, 512)            0         ['inception_4b/output[0][0]']
#  agePooling2D)
#
#  average_pooling2d_14 (Aver  (None, 1, 1, 832)            0         ['max_pooling2d_33[0][0]']
#  agePooling2D)
#
#  inception_5b/1x1 (Conv2D)   (None, 7, 7, 384)            319872    ['inception_5a/output[0][0]']
#
#  inception_5b/3x3 (Conv2D)   (None, 7, 7, 384)            663936    ['inception_5b/3x3_reduce[0][0
#                                                                     ]']
#
#  inception_5b/5x5 (Conv2D)   (None, 7, 7, 128)            153728    ['inception_5b/5x5_reduce[0][0
#                                                                     ]']
#
#  inception_5b/pool_proj (Co  (None, 7, 7, 128)            106624    ['inception_5b/pool[0][0]']
#  nv2D)
#
#  conv2d_42 (Conv2D)          (None, 4, 4, 128)            65664     ['average_pooling2d_13[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 1, 1, 128)            106624    ['average_pooling2d_14[0][0]']
#
#  inception_5b/output (Conca  (None, 7, 7, 1024)           0         ['inception_5b/1x1[0][0]',
#  tenate)                                                             'inception_5b/3x3[0][0]',
#                                                                      'inception_5b/5x5[0][0]',
#                                                                      'inception_5b/pool_proj[0][0]
#                                                                     ']
#
#  flatten_13 (Flatten)        (None, 2048)                 0         ['conv2d_42[0][0]']
#
#  flatten_14 (Flatten)        (None, 128)                  0         ['conv2d_43[0][0]']
#
#  average_pooling2d_15 (Aver  (None, 7, 7, 1024)           0         ['inception_5b/output[0][0]']
#  agePooling2D)
#
#  dense_21 (Dense)            (None, 256)                  524544    ['flatten_13[0][0]']
#
#  dense_23 (Dense)            (None, 256)                  33024     ['flatten_14[0][0]']
#
#  flatten_15 (Flatten)        (None, 50176)                0         ['average_pooling2d_15[0][0]']
#
#  dropout_12 (Dropout)        (None, 256)                  0         ['dense_21[0][0]']
#
#  dropout_13 (Dropout)        (None, 256)                  0         ['dense_23[0][0]']
#
#  dropout_14 (Dropout)        (None, 50176)                0         ['flatten_15[0][0]']
#
#  dense_22 (Dense)            (None, 10)                   2570      ['dropout_12[0][0]']
#
#  dense_24 (Dense)            (None, 10)                   2570      ['dropout_13[0][0]']
#
#  dense_25 (Dense)            (None, 10)                   501770    ['dropout_14[0][0]']
#
# ==================================================================================================
# Total params: 7196862 (27.45 MB)
# Trainable params: 7196862 (27.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
