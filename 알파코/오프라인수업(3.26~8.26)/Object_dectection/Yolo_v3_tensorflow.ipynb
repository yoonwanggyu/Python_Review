# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonwanggyu/Self_Study/blob/main/%EC%95%8C%ED%8C%8C%EC%BD%94/%EC%98%A4%ED%94%84%EB%9D%BC%EC%9D%B8%EC%88%98%EC%97%85(3.26~8.26)/Object_dectection/Yolo_v3_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Yolo_v3_implementation

# %% [markdown]
# ## 2 way of shortcut connection
# - identity shortcut connection
# - projected shortcut connection

# %%
import tensorflow as tf
from tensorflow.keras import layers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# shortcut connection 시, 사용해야할 함수 : layers.Add()

# %%
def conv_block(x, filters, kernel_size, strides=1):
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same', activation='linear')(x)
    x = layers.BatchNormalization()(x)
    return x

# %%
def identity_block(inputs, filters, kernel_size, strides=1):
    shortcut = inputs

    x = conv_block(inputs, filters, 3)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = conv_block(x, filters, 3)

    x = layers.Add()([x, shortcut])
    x = layers.LeakyReLU(alpha=0.1)(x)

    return x

# %%
def bottleneck_identity_block(inputs, filters, kernel_size, strides=1):
    shortcut = inputs

    x = conv_block(inputs, filters, 1)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = conv_block(x, filters, 3)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = conv_block(x, filters*4, 1)


    x = layers.Add()([x, shortcut])
    x = layers.LeakyReLU(alpha=0.1)(x)

    return x

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def projection_block(inputs, filters, kernel_size, strides=1):
    shortcut = conv_block(inputs, filters, 1)

    x = conv_block(inputs, filters, 3)
    x = layers.LeakyReLU(alpha=0.1)(x)
    x = conv_block(x, filters, 3)

    x = layers.Add()([x, shortcut])
    x = layers.LeakyReLU(alpha=0.1)(x)
    return x

# %% [markdown]
# ## darknet-53

# %% [markdown]
# residual_block(inputs, filters, projected=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def conv_block(x, filters, kernel_size, strides=1, activation=True):
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same', activation='linear')(x)
    x = layers.BatchNormalization()(x)
    if activation:
        x = layers.LeakyReLU(alpha=0.1)(x)
    return x

def residual_block(inputs, filters, projected=False):
    if projected:
        shortcut = conv_block(inputs, filters*2, 1, activation=False)
    else:
        shortcut = inputs

    x = conv_block(inputs, filters, 1)
    x = conv_block(x, filters*2, 3, activation=False)

    x = layers.Add()([x, shortcut])
    x = layers.LeakyReLU(alpha=0.1)(x)
    return x


def darknet53(include_top=True, input_shape=(256, 256, 3), num_classes=1000):
    inputs = tf.keras.Input(shape=input_shape)

    # Block 1
    x = conv_block(inputs, 32, 3)
    x = conv_block(x, 64, 3, 2)

    # Block 2
    x = residual_block(x, 32)
    x = conv_block(x, 128, 3, 2)

    # Block 3
    for _ in range(2):
        x = residual_block(x, 64)
    x = conv_block(x, 256, 3, 2)

    # Block 4
    for _ in range(8):
        x = residual_block(x, 128)
    route_1 = x # 52x52x256
    x = conv_block(x, 512, 3, 2)

    # Block 5
    for _ in range(8):
        x = residual_block(x, 256)
    route_2 = x # 26x26x512
    x = conv_block(x, 1024, 3, 2)

    # Block 6
    for _ in range(4):
        x = residual_block(x, 512)
    route_3 = x # 13x13x1024
     # Output
    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    if include_top:
        return model
    else:
        return tf.keras.Model(inputs=inputs, outputs=[route_1, route_2, route_3])

# %%
darknet_53 = darknet53()
darknet_53.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_312 (Conv2D)            (None, 256, 256, 32  896         ['input_8[0][0]']
#                                 )
#
#  batch_normalization_312 (Batch  (None, 256, 256, 32  128        ['conv2d_312[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_312 (LeakyReLU)    (None, 256, 256, 32  0           ['batch_normalization_312[0][0]']
#                                 )
#
#  conv2d_313 (Conv2D)            (None, 128, 128, 64  18496       ['leaky_re_lu_312[0][0]']
#                                 )
#
#  batch_normalization_313 (Batch  (None, 128, 128, 64  256        ['conv2d_313[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_313 (LeakyReLU)    (None, 128, 128, 64  0           ['batch_normalization_313[0][0]']
#                                 )
#
#  conv2d_314 (Conv2D)            (None, 128, 128, 32  2080        ['leaky_re_lu_313[0][0]']
#                                 )
#
#  batch_normalization_314 (Batch  (None, 128, 128, 32  128        ['conv2d_314[0][0]']
#  Normalization)                 )
#
#  leaky_re_lu_314 (LeakyReLU)    (None, 128, 128, 32  0           ['batch_normalization_314[0][0]']
#                                 )
#
#  conv2d_315 (Conv2D)            (None, 128, 128, 64  18496       ['leaky_re_lu_314[0][0]']
#                                 )
#
#  batch_normalization_315 (Batch  (None, 128, 128, 64  256        ['conv2d_315[0][0]']
#  Normalization)                 )
#
#  add_138 (Add)                  (None, 128, 128, 64  0           ['batch_normalization_315[0][0]',
#                                 )                                 'leaky_re_lu_313[0][0]']
#
#  leaky_re_lu_315 (LeakyReLU)    (None, 128, 128, 64  0           ['add_138[0][0]']
#                                 )
#
#  conv2d_316 (Conv2D)            (None, 64, 64, 128)  73856       ['leaky_re_lu_315[0][0]']
#
#  batch_normalization_316 (Batch  (None, 64, 64, 128)  512        ['conv2d_316[0][0]']
#  Normalization)
#
#  leaky_re_lu_316 (LeakyReLU)    (None, 64, 64, 128)  0           ['batch_normalization_316[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 64, 64, 64)   8256        ['leaky_re_lu_316[0][0]']
#
#  batch_normalization_317 (Batch  (None, 64, 64, 64)  256         ['conv2d_317[0][0]']
#  Normalization)
#
#  leaky_re_lu_317 (LeakyReLU)    (None, 64, 64, 64)   0           ['batch_normalization_317[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 64, 64, 128)  73856       ['leaky_re_lu_317[0][0]']
#
#  batch_normalization_318 (Batch  (None, 64, 64, 128)  512        ['conv2d_318[0][0]']
#  Normalization)
#
#  add_139 (Add)                  (None, 64, 64, 128)  0           ['batch_normalization_318[0][0]',
#                                                                   'leaky_re_lu_316[0][0]']
#
#  leaky_re_lu_318 (LeakyReLU)    (None, 64, 64, 128)  0           ['add_139[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 64, 64, 64)   8256        ['leaky_re_lu_318[0][0]']
#
#  batch_normalization_319 (Batch  (None, 64, 64, 64)  256         ['conv2d_319[0][0]']
#  Normalization)
#
#  leaky_re_lu_319 (LeakyReLU)    (None, 64, 64, 64)   0           ['batch_normalization_319[0][0]']
#
#  conv2d_320 (Conv2D)            (None, 64, 64, 128)  73856       ['leaky_re_lu_319[0][0]']
#
#  batch_normalization_320 (Batch  (None, 64, 64, 128)  512        ['conv2d_320[0][0]']
#  Normalization)
#
#  add_140 (Add)                  (None, 64, 64, 128)  0           ['batch_normalization_320[0][0]',
#                                                                   'leaky_re_lu_318[0][0]']
#
#  leaky_re_lu_320 (LeakyReLU)    (None, 64, 64, 128)  0           ['add_140[0][0]']
#
#  conv2d_321 (Conv2D)            (None, 32, 32, 256)  295168      ['leaky_re_lu_320[0][0]']
#
#  batch_normalization_321 (Batch  (None, 32, 32, 256)  1024       ['conv2d_321[0][0]']
#  Normalization)
#
#  leaky_re_lu_321 (LeakyReLU)    (None, 32, 32, 256)  0           ['batch_normalization_321[0][0]']
#
#  conv2d_322 (Conv2D)            (None, 32, 32, 128)  32896       ['leaky_re_lu_321[0][0]']
#
#  batch_normalization_322 (Batch  (None, 32, 32, 128)  512        ['conv2d_322[0][0]']
#  Normalization)
#
#  leaky_re_lu_322 (LeakyReLU)    (None, 32, 32, 128)  0           ['batch_normalization_322[0][0]']
#
#  conv2d_323 (Conv2D)            (None, 32, 32, 256)  295168      ['leaky_re_lu_322[0][0]']
#
#  batch_normalization_323 (Batch  (None, 32, 32, 256)  1024       ['conv2d_323[0][0]']
#  Normalization)
#
#  add_141 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_323[0][0]',
#                                                                   'leaky_re_lu_321[0][0]']
#
#  leaky_re_lu_323 (LeakyReLU)    (None, 32, 32, 256)  0           ['add_141[0][0]']
#
#  conv2d_324 (Conv2D)            (None, 32, 32, 128)  32896       ['leaky_re_lu_323[0][0]']
#
#  batch_normalization_324 (Batch  (None, 32, 32, 128)  512        ['conv2d_324[0][0]']
#  Normalization)
#
#  leaky_re_lu_324 (LeakyReLU)    (None, 32, 32, 128)  0           ['batch_normalization_324[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 32, 32, 256)  295168      ['leaky_re_lu_324[0][0]']
#
#  batch_normalization_325 (Batch  (None, 32, 32, 256)  1024       ['conv2d_325[0][0]']
#  Normalization)
#
#  add_142 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_325[0][0]',
#                                                                   'leaky_re_lu_323[0][0]']
#
#  leaky_re_lu_325 (LeakyReLU)    (None, 32, 32, 256)  0           ['add_142[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 32, 32, 128)  32896       ['leaky_re_lu_325[0][0]']
#
#  batch_normalization_326 (Batch  (None, 32, 32, 128)  512        ['conv2d_326[0][0]']
#  Normalization)
#
#  leaky_re_lu_326 (LeakyReLU)    (None, 32, 32, 128)  0           ['batch_normalization_326[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 32, 32, 256)  295168      ['leaky_re_lu_326[0][0]']
#
#  batch_normalization_327 (Batch  (None, 32, 32, 256)  1024       ['conv2d_327[0][0]']
#  Normalization)
#
#  add_143 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_327[0][0]',
#                                                                   'leaky_re_lu_325[0][0]']
#
#  leaky_re_lu_327 (LeakyReLU)    (None, 32, 32, 256)  0           ['add_143[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 32, 32, 128)  32896       ['leaky_re_lu_327[0][0]']
#
#  batch_normalization_328 (Batch  (None, 32, 32, 128)  512        ['conv2d_328[0][0]']
#  Normalization)
#
#  leaky_re_lu_328 (LeakyReLU)    (None, 32, 32, 128)  0           ['batch_normalization_328[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 32, 32, 256)  295168      ['leaky_re_lu_328[0][0]']
#
#  batch_normalization_329 (Batch  (None, 32, 32, 256)  1024       ['conv2d_329[0][0]']
#  Normalization)
#
#  add_144 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_329[0][0]',
#                                                                   'leaky_re_lu_327[0][0]']
#
#  leaky_re_lu_329 (LeakyReLU)    (None, 32, 32, 256)  0           ['add_144[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 32, 32, 128)  32896       ['leaky_re_lu_329[0][0]']
#
#  batch_normalization_330 (Batch  (None, 32, 32, 128)  512        ['conv2d_330[0][0]']
#  Normalization)
#
#  leaky_re_lu_330 (LeakyReLU)    (None, 32, 32, 128)  0           ['batch_normalization_330[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 32, 32, 256)  295168      ['leaky_re_lu_330[0][0]']
#
#  batch_normalization_331 (Batch  (None, 32, 32, 256)  1024       ['conv2d_331[0][0]']
#  Normalization)
#
#  add_145 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_331[0][0]',
#                                                                   'leaky_re_lu_329[0][0]']
#
#  leaky_re_lu_331 (LeakyReLU)    (None, 32, 32, 256)  0           ['add_145[0][0]']
#
#  conv2d_332 (Conv2D)            (None, 32, 32, 128)  32896       ['leaky_re_lu_331[0][0]']
#
#  batch_normalization_332 (Batch  (None, 32, 32, 128)  512        ['conv2d_332[0][0]']
#  Normalization)
#
#  leaky_re_lu_332 (LeakyReLU)    (None, 32, 32, 128)  0           ['batch_normalization_332[0][0]']
#
#  conv2d_333 (Conv2D)            (None, 32, 32, 256)  295168      ['leaky_re_lu_332[0][0]']
#
#  batch_normalization_333 (Batch  (None, 32, 32, 256)  1024       ['conv2d_333[0][0]']
#  Normalization)
#
#  add_146 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_333[0][0]',
#                                                                   'leaky_re_lu_331[0][0]']
#
#  leaky_re_lu_333 (LeakyReLU)    (None, 32, 32, 256)  0           ['add_146[0][0]']
#
#  conv2d_334 (Conv2D)            (None, 32, 32, 128)  32896       ['leaky_re_lu_333[0][0]']
#
#  batch_normalization_334 (Batch  (None, 32, 32, 128)  512        ['conv2d_334[0][0]']
#  Normalization)
#
#  leaky_re_lu_334 (LeakyReLU)    (None, 32, 32, 128)  0           ['batch_normalization_334[0][0]']
#
#  conv2d_335 (Conv2D)            (None, 32, 32, 256)  295168      ['leaky_re_lu_334[0][0]']
#
#  batch_normalization_335 (Batch  (None, 32, 32, 256)  1024       ['conv2d_335[0][0]']
#  Normalization)
#
#  add_147 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_335[0][0]',
#                                                                   'leaky_re_lu_333[0][0]']
#
#  leaky_re_lu_335 (LeakyReLU)    (None, 32, 32, 256)  0           ['add_147[0][0]']
#
#  conv2d_336 (Conv2D)            (None, 32, 32, 128)  32896       ['leaky_re_lu_335[0][0]']
#
#  batch_normalization_336 (Batch  (None, 32, 32, 128)  512        ['conv2d_336[0][0]']
#  Normalization)
#
#  leaky_re_lu_336 (LeakyReLU)    (None, 32, 32, 128)  0           ['batch_normalization_336[0][0]']
#
#  conv2d_337 (Conv2D)            (None, 32, 32, 256)  295168      ['leaky_re_lu_336[0][0]']
#
#  batch_normalization_337 (Batch  (None, 32, 32, 256)  1024       ['conv2d_337[0][0]']
#  Normalization)
#
#  add_148 (Add)                  (None, 32, 32, 256)  0           ['batch_normalization_337[0][0]',
#                                                                   'leaky_re_lu_335[0][0]']
#
#  leaky_re_lu_337 (LeakyReLU)    (None, 32, 32, 256)  0           ['add_148[0][0]']
#
#  conv2d_338 (Conv2D)            (None, 16, 16, 512)  1180160     ['leaky_re_lu_337[0][0]']
#
#  batch_normalization_338 (Batch  (None, 16, 16, 512)  2048       ['conv2d_338[0][0]']
#  Normalization)
#
#  leaky_re_lu_338 (LeakyReLU)    (None, 16, 16, 512)  0           ['batch_normalization_338[0][0]']
#
#  conv2d_339 (Conv2D)            (None, 16, 16, 256)  131328      ['leaky_re_lu_338[0][0]']
#
#  batch_normalization_339 (Batch  (None, 16, 16, 256)  1024       ['conv2d_339[0][0]']
#  Normalization)
#
#  leaky_re_lu_339 (LeakyReLU)    (None, 16, 16, 256)  0           ['batch_normalization_339[0][0]']
#
#  conv2d_340 (Conv2D)            (None, 16, 16, 512)  1180160     ['leaky_re_lu_339[0][0]']
#
#  batch_normalization_340 (Batch  (None, 16, 16, 512)  2048       ['conv2d_340[0][0]']
#  Normalization)
#
#  add_149 (Add)                  (None, 16, 16, 512)  0           ['batch_normalization_340[0][0]',
#                                                                   'leaky_re_lu_338[0][0]']
#
#  leaky_re_lu_340 (LeakyReLU)    (None, 16, 16, 512)  0           ['add_149[0][0]']
#
#  conv2d_341 (Conv2D)            (None, 16, 16, 256)  131328      ['leaky_re_lu_340[0][0]']
#
#  batch_normalization_341 (Batch  (None, 16, 16, 256)  1024       ['conv2d_341[0][0]']
#  Normalization)
#
#  leaky_re_lu_341 (LeakyReLU)    (None, 16, 16, 256)  0           ['batch_normalization_341[0][0]']
#
#  conv2d_342 (Conv2D)            (None, 16, 16, 512)  1180160     ['leaky_re_lu_341[0][0]']
#
#  batch_normalization_342 (Batch  (None, 16, 16, 512)  2048       ['conv2d_342[0][0]']
#  Normalization)
#
#  add_150 (Add)                  (None, 16, 16, 512)  0           ['batch_normalization_342[0][0]',
#                                                                   'leaky_re_lu_340[0][0]']
#
#  leaky_re_lu_342 (LeakyReLU)    (None, 16, 16, 512)  0           ['add_150[0][0]']
#
#  conv2d_343 (Conv2D)            (None, 16, 16, 256)  131328      ['leaky_re_lu_342[0][0]']
#
#  batch_normalization_343 (Batch  (None, 16, 16, 256)  1024       ['conv2d_343[0][0]']
#  Normalization)
#
#  leaky_re_lu_343 (LeakyReLU)    (None, 16, 16, 256)  0           ['batch_normalization_343[0][0]']
#
#  conv2d_344 (Conv2D)            (None, 16, 16, 512)  1180160     ['leaky_re_lu_343[0][0]']
#
#  batch_normalization_344 (Batch  (None, 16, 16, 512)  2048       ['conv2d_344[0][0]']
#  Normalization)
#
#  add_151 (Add)                  (None, 16, 16, 512)  0           ['batch_normalization_344[0][0]',
#                                                                   'leaky_re_lu_342[0][0]']
#
#  leaky_re_lu_344 (LeakyReLU)    (None, 16, 16, 512)  0           ['add_151[0][0]']
#
#  conv2d_345 (Conv2D)            (None, 16, 16, 256)  131328      ['leaky_re_lu_344[0][0]']
#
#  batch_normalization_345 (Batch  (None, 16, 16, 256)  1024       ['conv2d_345[0][0]']
#  Normalization)
#
#  leaky_re_lu_345 (LeakyReLU)    (None, 16, 16, 256)  0           ['batch_normalization_345[0][0]']
#
#  conv2d_346 (Conv2D)            (None, 16, 16, 512)  1180160     ['leaky_re_lu_345[0][0]']
#
#  batch_normalization_346 (Batch  (None, 16, 16, 512)  2048       ['conv2d_346[0][0]']
#  Normalization)
#
#  add_152 (Add)                  (None, 16, 16, 512)  0           ['batch_normalization_346[0][0]',
#                                                                   'leaky_re_lu_344[0][0]']
#
#  leaky_re_lu_346 (LeakyReLU)    (None, 16, 16, 512)  0           ['add_152[0][0]']
#
#  conv2d_347 (Conv2D)            (None, 16, 16, 256)  131328      ['leaky_re_lu_346[0][0]']
#
#  batch_normalization_347 (Batch  (None, 16, 16, 256)  1024       ['conv2d_347[0][0]']
#  Normalization)
#
#  leaky_re_lu_347 (LeakyReLU)    (None, 16, 16, 256)  0           ['batch_normalization_347[0][0]']
#
#  conv2d_348 (Conv2D)            (None, 16, 16, 512)  1180160     ['leaky_re_lu_347[0][0]']
#
#  batch_normalization_348 (Batch  (None, 16, 16, 512)  2048       ['conv2d_348[0][0]']
#  Normalization)
#
#  add_153 (Add)                  (None, 16, 16, 512)  0           ['batch_normalization_348[0][0]',
#                                                                   'leaky_re_lu_346[0][0]']
#
#  leaky_re_lu_348 (LeakyReLU)    (None, 16, 16, 512)  0           ['add_153[0][0]']
#
#  conv2d_349 (Conv2D)            (None, 16, 16, 256)  131328      ['leaky_re_lu_348[0][0]']
#
#  batch_normalization_349 (Batch  (None, 16, 16, 256)  1024       ['conv2d_349[0][0]']
#  Normalization)
#
#  leaky_re_lu_349 (LeakyReLU)    (None, 16, 16, 256)  0           ['batch_normalization_349[0][0]']
#
#  conv2d_350 (Conv2D)            (None, 16, 16, 512)  1180160     ['leaky_re_lu_349[0][0]']
#
#  batch_normalization_350 (Batch  (None, 16, 16, 512)  2048       ['conv2d_350[0][0]']
#  Normalization)
#
#  add_154 (Add)                  (None, 16, 16, 512)  0           ['batch_normalization_350[0][0]',
#                                                                   'leaky_re_lu_348[0][0]']
#
#  leaky_re_lu_350 (LeakyReLU)    (None, 16, 16, 512)  0           ['add_154[0][0]']
#
#  conv2d_351 (Conv2D)            (None, 16, 16, 256)  131328      ['leaky_re_lu_350[0][0]']
#
#  batch_normalization_351 (Batch  (None, 16, 16, 256)  1024       ['conv2d_351[0][0]']
#  Normalization)
#
#  leaky_re_lu_351 (LeakyReLU)    (None, 16, 16, 256)  0           ['batch_normalization_351[0][0]']
#
#  conv2d_352 (Conv2D)            (None, 16, 16, 512)  1180160     ['leaky_re_lu_351[0][0]']
#
#  batch_normalization_352 (Batch  (None, 16, 16, 512)  2048       ['conv2d_352[0][0]']
#  Normalization)
#
#  add_155 (Add)                  (None, 16, 16, 512)  0           ['batch_normalization_352[0][0]',
#                                                                   'leaky_re_lu_350[0][0]']
#
#  leaky_re_lu_352 (LeakyReLU)    (None, 16, 16, 512)  0           ['add_155[0][0]']
#
#  conv2d_353 (Conv2D)            (None, 16, 16, 256)  131328      ['leaky_re_lu_352[0][0]']
#
#  batch_normalization_353 (Batch  (None, 16, 16, 256)  1024       ['conv2d_353[0][0]']
#  Normalization)
#
#  leaky_re_lu_353 (LeakyReLU)    (None, 16, 16, 256)  0           ['batch_normalization_353[0][0]']
#
#  conv2d_354 (Conv2D)            (None, 16, 16, 512)  1180160     ['leaky_re_lu_353[0][0]']
#
#  batch_normalization_354 (Batch  (None, 16, 16, 512)  2048       ['conv2d_354[0][0]']
#  Normalization)
#
#  add_156 (Add)                  (None, 16, 16, 512)  0           ['batch_normalization_354[0][0]',
#                                                                   'leaky_re_lu_352[0][0]']
#
#  leaky_re_lu_354 (LeakyReLU)    (None, 16, 16, 512)  0           ['add_156[0][0]']
#
#  conv2d_355 (Conv2D)            (None, 8, 8, 1024)   4719616     ['leaky_re_lu_354[0][0]']
#
#  batch_normalization_355 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_355[0][0]']
#  Normalization)
#
#  leaky_re_lu_355 (LeakyReLU)    (None, 8, 8, 1024)   0           ['batch_normalization_355[0][0]']
#
#  conv2d_356 (Conv2D)            (None, 8, 8, 512)    524800      ['leaky_re_lu_355[0][0]']
#
#  batch_normalization_356 (Batch  (None, 8, 8, 512)   2048        ['conv2d_356[0][0]']
#  Normalization)
#
#  leaky_re_lu_356 (LeakyReLU)    (None, 8, 8, 512)    0           ['batch_normalization_356[0][0]']
#
#  conv2d_357 (Conv2D)            (None, 8, 8, 1024)   4719616     ['leaky_re_lu_356[0][0]']
#
#  batch_normalization_357 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_357[0][0]']
#  Normalization)
#
#  add_157 (Add)                  (None, 8, 8, 1024)   0           ['batch_normalization_357[0][0]',
#                                                                   'leaky_re_lu_355[0][0]']
#
#  leaky_re_lu_357 (LeakyReLU)    (None, 8, 8, 1024)   0           ['add_157[0][0]']
#
#  conv2d_358 (Conv2D)            (None, 8, 8, 512)    524800      ['leaky_re_lu_357[0][0]']
#
#  batch_normalization_358 (Batch  (None, 8, 8, 512)   2048        ['conv2d_358[0][0]']
#  Normalization)
#
#  leaky_re_lu_358 (LeakyReLU)    (None, 8, 8, 512)    0           ['batch_normalization_358[0][0]']
#
#  conv2d_359 (Conv2D)            (None, 8, 8, 1024)   4719616     ['leaky_re_lu_358[0][0]']
#
#  batch_normalization_359 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_359[0][0]']
#  Normalization)
#
#  add_158 (Add)                  (None, 8, 8, 1024)   0           ['batch_normalization_359[0][0]',
#                                                                   'leaky_re_lu_357[0][0]']
#
#  leaky_re_lu_359 (LeakyReLU)    (None, 8, 8, 1024)   0           ['add_158[0][0]']
#
#  conv2d_360 (Conv2D)            (None, 8, 8, 512)    524800      ['leaky_re_lu_359[0][0]']
#
#  batch_normalization_360 (Batch  (None, 8, 8, 512)   2048        ['conv2d_360[0][0]']
#  Normalization)
#
#  leaky_re_lu_360 (LeakyReLU)    (None, 8, 8, 512)    0           ['batch_normalization_360[0][0]']
#
#  conv2d_361 (Conv2D)            (None, 8, 8, 1024)   4719616     ['leaky_re_lu_360[0][0]']
#
#  batch_normalization_361 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_361[0][0]']
#  Normalization)
#
#  add_159 (Add)                  (None, 8, 8, 1024)   0           ['batch_normalization_361[0][0]',
#                                                                   'leaky_re_lu_359[0][0]']
#
#  leaky_re_lu_361 (LeakyReLU)    (None, 8, 8, 1024)   0           ['add_159[0][0]']
#
#  conv2d_362 (Conv2D)            (None, 8, 8, 512)    524800      ['leaky_re_lu_361[0][0]']
#
#  batch_normalization_362 (Batch  (None, 8, 8, 512)   2048        ['conv2d_362[0][0]']
#  Normalization)
#
#  leaky_re_lu_362 (LeakyReLU)    (None, 8, 8, 512)    0           ['batch_normalization_362[0][0]']
#
#  conv2d_363 (Conv2D)            (None, 8, 8, 1024)   4719616     ['leaky_re_lu_362[0][0]']
#
#  batch_normalization_363 (Batch  (None, 8, 8, 1024)  4096        ['conv2d_363[0][0]']
#  Normalization)
#
#  add_160 (Add)                  (None, 8, 8, 1024)   0           ['batch_normalization_363[0][0]',
#                                                                   'leaky_re_lu_361[0][0]']
#
#  leaky_re_lu_363 (LeakyReLU)    (None, 8, 8, 1024)   0           ['add_160[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 1024)        0           ['leaky_re_lu_363[0][0]']
#  obalAveragePooling2D)
#
#  dense_6 (Dense)                (None, 1000)         1025000     ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 41,663,496
# Trainable params: 41,627,784
# Non-trainable params: 35,712
# __________________________________________________________________________________________________

# %% [markdown]
# ## Yolo v3

# %%
    # layer     filters    size              input                output
    #     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32
    #     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64
    #     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32
    #     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64
    #     4 shortcut 1
    #     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128
    #     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64
    #     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128
    #     8 shortcut 5
    #     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64
    #    10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128
    #    11 shortcut 8
    #    12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256
    #    13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #    14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #    15 shortcut 12
    #    16 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #    17 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #    18 shortcut 15
    #    19 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #    20 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #    21 shortcut 18
    #    22 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #    23 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #    24 shortcut 21
    #    25 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #    26 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #    27 shortcut 24
    #    28 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #    29 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #    30 shortcut 27
    #    31 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #    32 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #    33 shortcut 30
    #    34 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #    35 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #    36 shortcut 33
    #    37 conv    512  3 x 3 / 2    52 x  52 x 256   ->    26 x  26 x 512
    #    38 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    39 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    40 shortcut 37
    #    41 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    42 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    43 shortcut 40
    #    44 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    45 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    46 shortcut 43
    #    47 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    48 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    49 shortcut 46
    #    50 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    51 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    52 shortcut 49
    #    53 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    54 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    55 shortcut 52
    #    56 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    57 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    58 shortcut 55
    #    59 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    60 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    61 shortcut 58
    #    62 conv   1024  3 x 3 / 2    26 x  26 x 512   ->    13 x  13 x1024
    #    63 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
    #    64 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
    #    65 shortcut 62
    #    66 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
    #    67 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
    #    68 shortcut 65
    #    69 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
    #    70 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
    #    71 shortcut 68
    #    72 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
    #    73 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
    #    74 shortcut 71
    #    75 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
    #    76 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
    #    77 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
    #    78 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
    #    79 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
    #    80 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
    #    81 conv    255  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 255
    #    82 detection
    #    83 route  79
    #    84 conv    256  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 256
    #    85 upsample           * 2    13 x  13 x 256   ->    26 x  26 x 256
    #    86 route  85 61
    #     87 conv    256  1 x 1 / 1    26 x  26 x 768   ->    26 x  26 x 256
    #    88 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    89 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    90 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    91 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
    #    92 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
    #    93 conv    255  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 255
    #    94 detection
    #    95 route  91
    #    96 conv    128  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 128
    #    97 upsample           * 2    26 x  26 x 128   ->    52 x  52 x 128
    #    98 route  97 36
    #    99 conv    128  1 x 1 / 1    52 x  52 x 384   ->    52 x  52 x 128
    #   100 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #   101 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #   102 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #   103 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
    #   104 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
    #   105 conv    255  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 255
    #   106 detection

# 출처 : Deep Learning Bible - 4. Object Detection

# %%
# darknet backbone
# block 4 -> route 1
# block 5 -> route 2
# block 6 -> route 3


# yolo v3 architecture
# block 6 : route 3 -> yolo_block_1
# yolo_block_1
#    conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
#    conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
#    conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
#    conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
#    conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512

# yolo_head_1
#    conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
#    conv    255  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 255
#    detection

# yolo_block_1 -> conv -> upsample
#    conv    256  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 256
#    upsample           * 2    13 x  13 x 256   ->    26 x  26 x 256
#    concat (route 2, upsample) -> yolo_block_2

# yolo_block_2
#    conv    256  1 x 1 / 1    26 x  26 x 768   ->    26 x  26 x 256
#    conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
#    conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
#    conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
#    conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256

# yolo_head_2
#    conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
#    conv    255  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 255
#    detection

# yolo_block_2 -> conv -> upsample
#    conv    128  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 128
#    upsample           * 2    26 x  26 x 128   ->    52 x  52 x 128
#    concat (route 1, upsample) -> yolo_block_3

# yolo_block_3
#    conv    128  1 x 1 / 1    52 x  52 x 384   ->    52 x  52 x 128
#    conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
#    conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
#    conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
#    conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128

# yolo_head_3
#    conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
#    conv    255  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 255
#    detection

# %%
def yolo_head(x, filters, num_anchors, num_classes):
    x = conv_block(x, filters, 3)

    # detection
    x = conv_block(x, num_anchors*(4+1+num_classes), 1)

    return x

def yolo_block(inputs, filters):
    x = conv_block(inputs, filters, 1)
    x = conv_block(x, filters*2, 3)
    x = conv_block(x, filters, 1)
    x = conv_block(x, filters*2, 3)
    x = conv_block(x, filters, 1)
    return x

def yolo_v3(input_shape=(416, 416, 3), num_anchors=3, num_classes=80):
    # backbone : darknet 53
    # - input : (416, 416, 3) image
    # - output : route1, route2, route3
    darknet_53 = darknet53(include_top=False, input_shape=(416, 416, 3))

    inputs = tf.keras.Input(shape=input_shape)
    route1, route2, route3 = darknet_53(inputs)

    # 13x13x255 detection
    x = yolo_block(route3, 512)
    output_l_scale = yolo_head(x, 1024, num_anchors, num_classes)

    # 26x26x255 detection
    x = conv_block(x, 256, 1)
    x = tf.keras.layers.UpSampling2D(2)(x)
    x = tf.keras.layers.Concatenate()([x, route2])
    x = yolo_block(x, 256)
    output_m_scale = yolo_head(x, 512, num_anchors, num_classes)

    # 52x52x255 detection
    x = conv_block(x, 128, 1)
    x = tf.keras.layers.UpSampling2D(2)(x)
    x = tf.keras.layers.Concatenate()([x, route1])
    x = yolo_block(x, 128)
    output_s_scale = yolo_head(x, 256, num_anchors, num_classes)

    outputs = [output_l_scale, output_m_scale, output_s_scale]
    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    return model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num_anchors = 3
num_classes = 80
